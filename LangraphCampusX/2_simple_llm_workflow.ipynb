# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os 
from dotenv import load_dotenv

api_key = api_key=os.environ.get("GEMINI_API_KEY")

model = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",  # Use the correct model
    google_api_key=api_key 
)
# Out:
# E0000 00:00:1762714107.353963  740247 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.

# %%
# model = ChatOpenAI()

# %%
# create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# The distance between the Earth and the Moon varies because the Moon's orbit is an ellipse, not a perfect circle.
#
# *   **Average distance:** 384,400 kilometers (238,900 miles)
#
# *   **Closest point (perigee):** Around 363,104 kilometers (225,623 miles)
#
# *   **Farthest point (apogee):** Around 405,696 kilometers (252,088 miles)

# %%
model.invoke('How far is moon from the earth?').content
# Out:
# "The distance between the Earth and the Moon isn't constant, as the Moon's orbit is an ellipse. However, we can give you some key figures:\n\n*   **Average distance:** 384,400 kilometers (238,900 miles)\n\n*   **Closest point (perigee):** Around 363,104 kilometers (225,623 miles)\n\n*   **Farthest point (apogee):** Around 405,696 kilometers (252,088 miles)"
