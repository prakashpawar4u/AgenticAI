# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
# load_dotenv()

# model = ChatOpenAI()

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os 
from dotenv import load_dotenv
load_dotenv()
api_key = api_key=os.environ.get("GEMINI_API_KEY")

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",  # Use the correct model
    google_api_key=api_key 
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762714184.206988  748272 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = llm.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = llm.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': '## Blog Outline: Rise of AI in India\n\n**I. Introduction (Hook the Reader)**\n\n   * **A. Opening Statement:** Start with a captivating statistic or a real-world example showcasing the impact of AI in India (e.g., "India is projected to have the highest AI skill penetration globally by 2030...")\n   * **B. Brief Definition of AI:** Define Artificial Intelligence in a simple, accessible manner for a broad audience. Avoid overly technical jargon.\n   * **C. Thesis Statement:**  Clearly state the blog\'s central argument:  "AI is rapidly transforming India\'s economy, society, and governance, presenting both significant opportunities and challenges that require careful consideration and strategic planning."\n   * **D. Blog Roadmap:** Briefly outline the topics to be covered in the blog post. (e.g., "This blog explores the key drivers of AI adoption in India, its impact across various sectors, the challenges it poses, and the steps being taken to foster responsible AI development.")\n\n**II. Key Drivers of AI Adoption in India**\n\n   * **A. Government Initiatives and Policies:**\n      *   1.  **National Strategy for Artificial Intelligence:** Discuss the key objectives and initiatives outlined in the government\'s AI strategy.\n      *   2.  **Investment in Research and Development:** Highlight government funding for AI research and development projects in academic institutions and private sector.\n      *   3.  **Skill Development Programs:** Mention initiatives aimed at training individuals in AI-related skills (e.g., NASSCOM FutureSkills Prime, Skill India Mission).\n      *   4.  **Data Availability and Infrastructure:** Discuss the availability of data resources and the development of robust digital infrastructure (e.g., Digital India initiative) to support AI development.\n   * **B. Booming IT and Tech Sector:**\n      *   1.  **Strong IT Services Industry:** Emphasize the role of the existing IT services industry in providing a foundation for AI adoption and implementation.\n      *   2.  **Startup Ecosystem:** Highlight the growth of AI-focused startups in India and their innovative solutions.\n      *   3.  **Investment in AI Startups:** Discuss the increasing venture capital funding flowing into Indian AI startups.\n   * **C. Growing Data Availability:**\n      *   1.  **Large Population and Increasing Digital Penetration:** Explain how India\'s large population and increasing internet access are generating vast amounts of data.\n      *   2.  **Data Localization Policies:** Briefly mention any data localization policies that are influencing data availability for AI development within India.\n   * **D. Cost-Effectiveness and Accessibility:**\n      *   1.  **Affordable AI Solutions:** Discuss how the cost of AI solutions is becoming more accessible to businesses of all sizes in India.\n      *   2.  **Talent Pool:** Highlight the availability of a skilled and cost-effective AI talent pool in India.\n\n**III. Impact of AI Across Various Sectors in India**\n\n   * **A. Healthcare:**\n      *   1.  **Diagnostics and Treatment:** Examples of AI-powered diagnostic tools and personalized treatment plans.\n      *   2.  **Drug Discovery:** Mention AI\'s role in accelerating drug discovery and development processes.\n      *   3.  **Remote Healthcare and Telemedicine:** Discuss the use of AI in providing remote healthcare services, especially in rural areas.\n   * **B. Agriculture:**\n      *   1.  **Precision Farming:**  Explain how AI is used to optimize crop yields, manage irrigation, and predict weather patterns.\n      *   2.  **Pest and Disease Detection:** Highlight AI-powered tools for early detection of pests and diseases in crops.\n      *   3.  **Supply Chain Optimization:** Discuss how AI can improve efficiency and reduce waste in the agricultural supply chain.\n   * **C. Finance:**\n      *   1.  **Fraud Detection:** Examples of AI-powered fraud detection systems in ba ...

# %%
print(final_state['outline'])
# Out:
# ## Blog Outline: Rise of AI in India
#
# **I. Introduction (Hook the Reader)**
#
#    * **A. Opening Statement:** Start with a captivating statistic or a real-world example showcasing the impact of AI in India (e.g., "India is projected to have the highest AI skill penetration globally by 2030...")
#    * **B. Brief Definition of AI:** Define Artificial Intelligence in a simple, accessible manner for a broad audience. Avoid overly technical jargon.
#    * **C. Thesis Statement:**  Clearly state the blog's central argument:  "AI is rapidly transforming India's economy, society, and governance, presenting both significant opportunities and challenges that require careful consideration and strategic planning."
#    * **D. Blog Roadmap:** Briefly outline the topics to be covered in the blog post. (e.g., "This blog explores the key drivers of AI adoption in India, its impact across various sectors, the challenges it poses, and the steps being taken to foster responsible AI development.")
#
# **II. Key Drivers of AI Adoption in India**
#
#    * **A. Government Initiatives and Policies:**
#       *   1.  **National Strategy for Artificial Intelligence:** Discuss the key objectives and initiatives outlined in the government's AI strategy.
#       *   2.  **Investment in Research and Development:** Highlight government funding for AI research and development projects in academic institutions and private sector.
#       *   3.  **Skill Development Programs:** Mention initiatives aimed at training individuals in AI-related skills (e.g., NASSCOM FutureSkills Prime, Skill India Mission).
#       *   4.  **Data Availability and Infrastructure:** Discuss the availability of data resources and the development of robust digital infrastructure (e.g., Digital India initiative) to support AI development.
#    * **B. Booming IT and Tech Sector:**
#       *   1.  **Strong IT Services Industry:** Emphasize the role of the existing IT services industry in providing a foundation for AI adoption and implementation.
#       *   2.  **Startup Ecosystem:** Highlight the growth of AI-focused startups in India and their innovative solutions.
#       *   3.  **Investment in AI Startups:** Discuss the increasing venture capital funding flowing into Indian AI startups.
#    * **C. Growing Data Availability:**
#       *   1.  **Large Population and Increasing Digital Penetration:** Explain how India's large population and increasing internet access are generating vast amounts of data.
#       *   2.  **Data Localization Policies:** Briefly mention any data localization policies that are influencing data availability for AI development within India.
#    * **D. Cost-Effectiveness and Accessibility:**
#       *   1.  **Affordable AI Solutions:** Discuss how the cost of AI solutions is becoming more accessible to businesses of all sizes in India.
#       *   2.  **Talent Pool:** Highlight the availability of a skilled and cost-effective AI talent pool in India.
#
# **III. Impact of AI Across Various Sectors in India**
#
#    * **A. Healthcare:**
#       *   1.  **Diagnostics and Treatment:** Examples of AI-powered diagnostic tools and personalized treatment plans.
#       *   2.  **Drug Discovery:** Mention AI's role in accelerating drug discovery and development processes.
#       *   3.  **Remote Healthcare and Telemedicine:** Discuss the use of AI in providing remote healthcare services, especially in rural areas.
#    * **B. Agriculture:**
#       *   1.  **Precision Farming:**  Explain how AI is used to optimize crop yields, manage irrigation, and predict weather patterns.
#       *   2.  **Pest and Disease Detection:** Highlight AI-powered tools for early detection of pests and diseases in crops.
#       *   3.  **Supply Chain Optimization:** Discuss how AI can improve efficiency and reduce waste in the agricultural supply chain.
#    * **C. Finance:**
#       *   1.  **Fraud Detection:** Examples of AI-powered fraud detection systems in banking and finance.
#       *   2.  **Personalized Financial Services:** Discuss the use of AI in providing personalized financial advice and recommendations.
#       *   3.  **Risk Management:** Highlight AI's role in assessing and managing financial risks.
#    * **D. Education:**
#       *   1.  **Personalized Learning:** Explain how AI can be used to create personalized learning experiences for students.
#       *   2.  **Automated Grading and Feedback:** Discuss the use of AI in automating grading tasks and providing personalized feedback to students.
#       *   3.  **Accessibility and Inclusivity:**  Mention how AI can help make education more accessible to students with disabilities.
#    * **E. Manufacturing:**
#       *   1.  **Predictive Maintenance:** Discuss the use of AI in predicting equipment failures and optimizing maintenance schedules.
#       *   2.  **Quality Control:** Highlight AI-powered systems for detecting defects and ensuring product quality.
#       *   3.  **Automation and Robotics:** Explain how AI is driving automation and the use of robots in manufacturing processes.
#
# **IV. Challenges and Concerns**
#
#    * **A. Ethical Considerations:**
#       *   1.  **Bias in AI Algorithms:** Discuss the potential for bias in AI algorithms and the importance of developing fair and unbiased AI systems.
#       *   2.  **Privacy Concerns:** Highlight the importance of protecting personal data and ensuring data privacy in the age of AI.
#       *   3.  **Accountability and Transparency:** Discuss the need for clear lines of accountability and transparency in AI decision-making processes.
#    * **B. Job Displacement:**
#       *   1.  **Automation and Job Losses:** Acknowledge the potential for job displacement due to automation driven by AI.
#       *   2.  **Reskilling and Upskilling Initiatives:** Emphasize the importance of investing in reskilling and upskilling programs to prepare the workforce for the future of work.
#    * **C. Infrastructure Gaps:**
#       *   1.  **Digital Divide:** Discuss the digital divide in India and the need to ensure equitable access to technology and internet connectivity.
#       *   2.  **Data Security and Cybersecurity:** Highlight the importance of strengthening data security and cybersecurity measures to protect against cyber threats.
#    * **D. Lack of Awareness and Understanding:**
#       *   1.  **Public Perception of AI:** Discuss the need to improve public understanding of AI and address misconceptions.
#       *   2.  **Building Trust in AI:** Emphasize the importance of building trust in AI systems through transparency and ethical practices.
#
# **V.  The Way Forward: Fostering Responsible AI Development**
#
#    * **A. Strengthening Regulatory Frameworks:**
#       *   1.  **Developing Clear AI Regulations:** Discuss the need for clear and comprehensive regulations to govern the development and deployment of AI systems.
#       *   2.  **Promoting Ethical AI Practices:** Emphasize the importance of promoting ethical AI practices and guidelines.
#    * **B. Investing in Education and Training:**
#       *   1.  **Expanding AI Education Programs:** Advocate for expanding AI education programs at all levels, from primary school to higher education.
#       *   2.  **Promoting Lifelong Learning:** Encourage lifelong learning and continuous skill development to adapt to the changing demands of the AI-driven economy.
#    * **C. Fostering Collaboration and Innovation:**
#       *   1.  **Encouraging Public-Private Partnerships:** Highlight the importance of collaboration between government, industry, and academia to drive AI innovation.
#       *   2.  **Supporting AI Startups:**  Continue to support and encourage the growth of AI startups in India.
#    * **D. Addressing Ethical Concerns Proactively:**
#       *   1.  **Developing AI Ethics Frameworks:** Emphasize the need to develop robust AI ethics frameworks to guide the development and deployment of AI systems.
#       *   2.  **Promoting Diversity and Inclusion in AI Development:** Encourage diversity and inclusion in AI development teams to ensure that AI systems are fair and unbiased.
#
# **VI. Conclusion (Summarize and Call to Action)**
#
#    * **A. Recap of Key Points:** Briefly summarize the main points discussed in the blog post.
#    * **B. Reinforce the Thesis Statement:** Reiterate the blog's central argument about the transformative potential of AI in India.
#    * **C. Call to Action:** Encourage readers to engage in the conversation about AI, participate in AI-related initiatives, and advocate for responsible AI development.
#    * **D. Final Thought:** End with a positive and optimistic outlook on the future of AI in India, emphasizing the potential for AI to improve lives and drive economic growth.
#
# **VII. Optional Elements:**
#
#    * **A. Visuals:** Include relevant images, charts, and graphs to illustrate key points and enhance engagement.
#    * **B. Quotes:** Incorporate quotes from industry experts, government officials, or AI researchers to add credibility and depth to the blog post.
#    * **C. Case Studies:** Include short case studies of successful AI implementations in India.
#    * **D. Links to Resources:** Provide links to relevant websites, reports, and articles for readers who want to learn more about AI in India.
#
# This detailed outline provides a comprehensive framework for writing a compelling and informative blog post on the rise of AI in India. Remember to tailor the content to your target audience and use clear, concise language to ensure maximum readability. Good luck!

# %%
print(final_state['content'])
# Out:
# ## Rise of AI in India: Opportunity Knocks, Responsibility Calls
#
# **I. Introduction (Hook the Reader)**
#
# **A. Opening Statement:** India is projected to have the highest AI skill penetration globally by 2030, potentially adding $1 trillion to its economy. This isn't just a statistic; it's a glimpse into a future rapidly being shaped by Artificial Intelligence.
#
# **B. Brief Definition of AI:** Simply put, Artificial Intelligence (AI) is the ability of machines to mimic human intelligence, performing tasks that typically require human intellect, such as learning, problem-solving, and decision-making. Think of it as giving computers the power to think and act like humans.
#
# **C. Thesis Statement:** AI is rapidly transforming India's economy, society, and governance, presenting both significant opportunities and challenges that require careful consideration and strategic planning.
#
# **D. Blog Roadmap:** This blog explores the key drivers of AI adoption in India, its impact across various sectors, the challenges it poses, and the steps being taken to foster responsible AI development.
#
# **II. Key Drivers of AI Adoption in India**
#
# **A. Government Initiatives and Policies:**
#
# 1.  **National Strategy for Artificial Intelligence:** The "AI for All" strategy aims to leverage AI for inclusive growth, focusing on areas like healthcare, agriculture, education, smart cities, and transportation. It emphasizes ethical AI development and deployment.
# 2.  **Investment in Research and Development:** The government is actively funding AI research through institutions like IITs and IISc, as well as supporting private sector initiatives.  Schemes like the Atal Innovation Mission further encourage innovation in AI and related fields.
# 3.  **Skill Development Programs:** Initiatives like NASSCOM FutureSkills Prime and the Skill India Mission are crucial in bridging the AI skills gap. These programs offer training in AI, machine learning, data science, and other relevant areas.
# 4.  **Data Availability and Infrastructure:** The Digital India initiative has significantly improved internet access and digital literacy, generating vast amounts of data.  The government is also working on creating a national data governance framework to ensure responsible data sharing and utilization.
#
# **B. Booming IT and Tech Sector:**
#
# 1.  **Strong IT Services Industry:** India's established IT services industry provides a strong foundation for AI adoption. Companies like TCS, Infosys, and Wipro are actively integrating AI into their service offerings, helping clients across the globe implement AI solutions.
# 2.  **Startup Ecosystem:** India's startup ecosystem is vibrant and growing, with a significant number of startups focused on AI-powered solutions across various sectors.  These startups are driving innovation and disruption.
# 3.  **Investment in AI Startups:** Venture capital funding for Indian AI startups has been steadily increasing, reflecting investor confidence in the potential of the Indian AI market.  Major venture capital firms are actively seeking out promising AI startups to invest in.
#
# **C. Growing Data Availability:**
#
# 1.  **Large Population and Increasing Digital Penetration:** India's large population, coupled with increasing internet and mobile penetration, is generating a massive amount of data. This data is a crucial resource for training and developing AI models.
# 2.  **Data Localization Policies:** While debated, data localization policies aim to ensure that data generated within India is stored and processed within the country, potentially boosting AI development within the nation.
#
# **D. Cost-Effectiveness and Accessibility:**
#
# 1.  **Affordable AI Solutions:** The cost of AI solutions is becoming increasingly affordable in India, making it accessible to businesses of all sizes. Cloud-based AI platforms and open-source tools are contributing to this trend.
# 2.  **Talent Pool:** India has a large and relatively cost-effective AI talent pool, making it an attractive destination for companies looking to develop and implement AI solutions.
#
# **III. Impact of AI Across Various Sectors in India**
#
# **A. Healthcare:**
#
# 1.  **Diagnostics and Treatment:** AI is being used to analyze medical images (X-rays, CT scans) to detect diseases like cancer with greater accuracy and speed. Personalized treatment plans are also being developed based on AI-powered analysis of patient data.
# 2.  **Drug Discovery:** AI is accelerating the drug discovery process by identifying potential drug candidates and predicting their efficacy. This can significantly reduce the time and cost involved in developing new drugs.
# 3.  **Remote Healthcare and Telemedicine:** AI-powered chatbots and virtual assistants are providing remote healthcare services, especially in rural areas where access to doctors is limited. AI can also monitor patients remotely and alert healthcare providers to potential problems.
#
# **B. Agriculture:**
#
# 1.  **Precision Farming:** AI is used to analyze soil conditions, weather patterns, and crop data to optimize irrigation, fertilization, and pesticide application. This leads to increased crop yields and reduced resource consumption.
# 2.  **Pest and Disease Detection:** AI-powered drones and sensors can detect pests and diseases in crops early on, allowing farmers to take timely action and prevent widespread damage.
# 3.  **Supply Chain Optimization:** AI can improve efficiency and reduce waste in the agricultural supply chain by predicting demand, optimizing logistics, and minimizing spoilage.
#
# **C. Finance:**
#
# 1.  **Fraud Detection:** AI is used to analyze transaction data and identify fraudulent activities in real-time, preventing financial losses for banks and customers.
# 2.  **Personalized Financial Services:** AI-powered chatbots and robo-advisors are providing personalized financial advice and recommendations to customers, helping them manage their finances more effectively.
# 3.  **Risk Management:** AI is used to assess and manage financial risks by analyzing market data, predicting economic trends, and identifying potential vulnerabilities.
#
# **D. Education:**
#
# 1.  **Personalized Learning:** AI can analyze student performance data and identify individual learning needs, allowing educators to create personalized learning experiences that cater to each student's strengths and weaknesses.
# 2.  **Automated Grading and Feedback:** AI can automate grading tasks for multiple-choice questions and essays, freeing up teachers' time to focus on more personalized instruction. AI can also provide students with personalized feedback on their work.
# 3.  **Accessibility and Inclusivity:** AI can help make education more accessible to students with disabilities by providing tools like text-to-speech, speech-to-text, and automated translation.
#
# **E. Manufacturing:**
#
# 1.  **Predictive Maintenance:** AI is used to analyze sensor data from machines and equipment to predict potential failures and optimize maintenance schedules. This reduces downtime and extends the lifespan of equipment.
# 2.  **Quality Control:** AI-powered vision systems can detect defects in products with greater accuracy and speed than human inspectors, ensuring product quality and reducing waste.
# 3.  **Automation and Robotics:** AI is driving automation and the use of robots in manufacturing processes, leading to increased efficiency, productivity, and safety.
#
# **IV. Challenges and Concerns**
#
# **A. Ethical Considerations:**
#
# 1.  **Bias in AI Algorithms:** AI algorithms can be biased if they are trained on biased data. This can lead to unfair or discriminatory outcomes, particularly for marginalized groups.
# 2.  **Privacy Concerns:** AI systems often collect and process large amounts of personal data, raising concerns about data privacy and security.
# 3.  **Accountability and Transparency:** It can be difficult to understand how AI systems make decisions, making it challenging to hold them accountable for their actions. Transparency in AI development and deployment is crucial.
#
# **B. Job Displacement:**
#
# 1.  **Automation and Job Losses:** AI-driven automation has the potential to displace workers in various industries, particularly those involved in repetitive or manual tasks.
# 2.  **Reskilling and Upskilling Initiatives:** Investing in reskilling and upskilling programs is essential to prepare the workforce for the future of work and help workers transition to new roles in the AI-driven economy.
#
# **C. Infrastructure Gaps:**
#
# 1.  **Digital Divide:** The digital divide in India means that many people, particularly in rural areas, lack access to technology and internet connectivity. This can limit their ability to benefit from AI.
# 2.  **Data Security and Cybersecurity:** Strengthening data security and cybersecurity measures is crucial to protect against cyber threats and ensure the integrity of AI systems.
#
# **D. Lack of Awareness and Understanding:**
#
# 1.  **Public Perception of AI:**  Many people have limited understanding of AI and may harbor misconceptions about its capabilities and potential impact.
# 2.  **Building Trust in AI:** Building trust in AI systems requires transparency, ethical practices, and public education.
#
# **V.  The Way Forward: Fostering Responsible AI Development**
#
# **A. Strengthening Regulatory Frameworks:**
#
# 1.  **Developing Clear AI Regulations:**  India needs clear and comprehensive regulations to govern the development and deployment of AI systems, addressing issues like data privacy, bias, and accountability.
# 2.  **Promoting Ethical AI Practices:**  The government and industry should work together to promote ethical AI practices and guidelines, ensuring that AI is used for good and in a responsible manner.
#
# **B. Investing in Education and Training:**
#
# 1.  **Expanding AI Education Programs:** Expanding AI education programs at all levels, from primary school to higher education, is crucial to prepare the next generation for the AI-driven economy.
# 2.  **Promoting Lifelong Learning:**  Encouraging lifelong learning and continuous skill development is essential to help workers adapt to the changing demands of the AI-driven economy.
#
# **C. Fostering Collaboration and Innovation:**
#
# 1.  **Encouraging Public-Private Partnerships:** Collaboration between government, industry, and academia is essential to drive AI innovation and address the challenges of AI adoption.
# 2.  **Supporting AI Startups:**  Continuing to support and encourage the growth of AI startups in India will foster innovation and create new economic opportunities.
#
# **D. Addressing Ethical Concerns Proactively:**
#
# 1.  **Developing AI Ethics Frameworks:** Developing robust AI ethics frameworks is crucial to guide the development and deployment of AI systems and ensure that they are used ethically and responsibly.
# 2.  **Promoting Diversity and Inclusion in AI Development:**  Encouraging diversity and inclusion in AI development teams is essential to ensure that AI systems are fair and unbiased and that they reflect the values and perspectives of all members of society.
#
# **VI. Conclusion (Summarize and Call to Action)**
#
# **A. Recap of Key Points:** AI is rapidly transforming India, driven by government initiatives, a booming tech sector, and growing data availability.  Its impact spans healthcare, agriculture, finance, education, and manufacturing, but ethical concerns, job displacement, and infrastructure gaps must be addressed.
#
# **B. Reinforce the Thesis Statement:** AI's transformative potential in India is undeniable, but its responsible development and deployment are crucial for realizing its full benefits and mitigating its risks.
#
# **C. Call to Action:**  Engage in the conversation about AI, participate in AI-related initiatives, advocate for responsible AI development, and demand transparency and accountability from AI systems.
#
# **D. Final Thought:** The future of AI in India is bright, offering the potential to improve lives, drive economic growth, and address some of the country's most pressing challenges. By embracing AI responsibly, India can become a global leader in this transformative technology.
#
# **VII. Optional Elements:**
#
# *   **Visuals:**  Include images of AI-powered agricultural drones, AI-based diagnostic tools, and graphs showing the growth of the Indian AI market.
# *   **Quotes:** "AI has the potential to revolutionize every sector of the Indian economy, but it is crucial that we develop and deploy AI responsibly, ensuring that it benefits all members of society." - *Quote from a government official*
# *   **Case Studies:**  Include a short case study of an Indian AI startup that is using AI to improve healthcare access in rural areas.
# *   **Links to Resources:** Provide links to the National Strategy for Artificial Intelligence, NASSCOM FutureSkills Prime, and other relevant resources.
